# %% [markdown]
# ## Import Library yang ingin Dipakai

# %%
import pandas as pd

# %% [markdown]
# ## Menampilkan Dataset

# %%
tampil = pd.read_csv ('K03_counter_strike_2.csv')
tampil
# Out:
#       time_left  ct_score  t_score       map  bomb_planted  ct_health  \
# 0        175.00       0.0      0.0  de_dust2         False      500.0
# 1        156.03       0.0      0.0  de_dust2         False      500.0
# 2         96.03       0.0      0.0  de_dust2         False      391.0
# 3         76.03       0.0      0.0  de_dust2         False      391.0
# 4        174.97       1.0      0.0  de_dust2         False      500.0
# ...         ...       ...      ...       ...           ...        ...
# 1995      74.90       7.0     10.0  de_train         False      327.0
# 1996      31.23       7.0     10.0  de_train          True      227.0
# 1997      11.23       7.0     10.0  de_train          True      185.0
# 1998     174.91       7.0     11.0  de_train         False      500.0
# 1999     114.90       7.0     11.0  de_train         False      500.0
#
#       t_health  ct_armor  t_armor  ct_money  t_money  ct_helmets  t_helmets  \
# ...

# %%
tampil.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   time_left     2000 non-null   float64
#  1   ct_score      2000 non-null   float64
#  2   t_score       2000 non-null   float64
#  3   map           2000 non-null   object
#  4   bomb_planted  2000 non-null   bool
#  5   ct_health     2000 non-null   float64
#  6   t_health      2000 non-null   float64
#  7   ct_armor      2000 non-null   float64
#  8   t_armor       2000 non-null   float64
#  9   ct_money      2000 non-null   float64
#  10  t_money       2000 non-null   float64
#  11  ct_helmets    2000 non-null   float64
#  12  t_helmets     2000 non-null   float64
#  13  round_winner  2000 non-null   object
# dtypes: bool(1), float64(11), object(2)
# memory usage: 205.2+ KB

# %%
jumlah_kosong = tampil.isna().sum()
jumlah_kosong
# Out:
# time_left       0
# ct_score        0
# t_score         0
# map             0
# bomb_planted    0
# ct_health       0
# t_health        0
# ct_armor        0
# t_armor         0
# ct_money        0
# t_money         0
# ct_helmets      0
# t_helmets       0
# round_winner    0
# dtype: int64

# %%
tampil.describe ()
# Out:
#          time_left     ct_score     t_score    ct_health     t_health  \
# count  2000.000000  2000.000000  2000.00000  2000.000000  2000.000000
# mean     95.630205     6.840000     6.28850   406.170500   402.987500
# std      53.734491     4.233599     4.19059   137.616258   137.699186
# min       0.050000     0.000000     0.00000     2.000000     0.000000
# 25%      54.910000     3.000000     3.00000   315.750000   328.750000
# 50%      94.910000     7.000000     6.00000   500.000000   500.000000
# 75%     156.425000    10.000000    10.00000   500.000000   500.000000
# max     175.000000    15.000000    15.00000   500.000000   500.000000
#
#           ct_armor     t_armor      ct_money       t_money   ct_helmets  \
# count  2000.000000  2000.00000   2000.000000   2000.000000  2000.000000
# mean    306.749000   309.54450   7867.350000  12377.600000     1.821500
# std     172.857221   168.68957   9017.491838  12209.581798     1.774884
# ...

# %%
print (tampil.columns)
# Out:
# Index(['time_left', 'ct_score', 't_score', 'map', 'bomb_planted', 'ct_health',
#        't_health', 'ct_armor', 't_armor', 'ct_money', 't_money', 'ct_helmets',
#        't_helmets', 'round_winner'],
#       dtype='object')

# %% [markdown]
# ## Preprosesing Data

# %%
from sklearn.preprocessing import LabelEncoder
for col in ['time_left', 'ct_score', 't_score', 'map', 'bomb_planted', 'ct_health',
    't_health', 'ct_armor', 't_armor', 'ct_money', 't_money', 'ct_helmets',
    't_helmets', 'round_winner'] :
    label_encoder = LabelEncoder()
    tampil[col] = label_encoder.fit_transform(tampil[col])

# %%
tampil
# Out:
#       time_left  ct_score  t_score  map  bomb_planted  ct_health  t_health  \
# 0           608         0        0    0             0        274       319
# 1           542         0        0    0             0        274       319
# 2           468         0        0    0             0        200       246
# 3           394         0        0    0             0        200       246
# 4           607         1        0    0             0        274       319
# ...         ...       ...      ...  ...           ...        ...       ...
# 1995        383         7       10    5             0        161       209
# 1996        205         7       10    5             1        101        70
# 1997         50         7       10    5             1         76        47
# 1998        601         7       11    5             0        274       319
# 1999        529         7       11    5             0        274       319
#
#       ct_armor  t_armor  ct_money  t_money  ct_helmets  t_helmets  \
# ...

# %% [markdown]
# ## Memisahkan Kolom Target

# %%
x = tampil.drop ('round_winner', axis=1)
y = tampil ['round_winner']

# %%
x
# Out:
#       time_left  ct_score  t_score  map  bomb_planted  ct_health  t_health  \
# 0           608         0        0    0             0        274       319
# 1           542         0        0    0             0        274       319
# 2           468         0        0    0             0        200       246
# 3           394         0        0    0             0        200       246
# 4           607         1        0    0             0        274       319
# ...         ...       ...      ...  ...           ...        ...       ...
# 1995        383         7       10    5             0        161       209
# 1996        205         7       10    5             1        101        70
# 1997         50         7       10    5             1         76        47
# 1998        601         7       11    5             0        274       319
# 1999        529         7       11    5             0        274       319
#
#       ct_armor  t_armor  ct_money  t_money  ct_helmets  t_helmets
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    1
# 1996    1
# 1997    1
# 1998    1
# 1999    0
# Name: round_winner, Length: 2000, dtype: int32

# %% [markdown]
# ## Splitting Data Testting dan Traning?

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 80 : 20

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2)

# %% [markdown]
# #### Desision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
modelDT = DecisionTreeClassifier (max_depth = 5)
modelDT.fit (x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
# Testing model untuk melakukan Prediksi
hasil_prediksi = modelDT.predict (x_test)

# %%
from sklearn.metrics import accuracy_score
hasil_prediksi_dt = modelDT.predict (x_test)
print ('Akurasi Model : ', accuracy_score (y_test, hasil_prediksi_dt)*100,('%'))
# Out:
# Akurasi Model :  74.0 %

# %% [markdown]
# ## Test Data

# %%
data_baru = ([[601,7,11,5,0,274,319,1,0,260,492,0,0]])
hasil_prediksi = modelDT.predict (data_baru)
if hasil_prediksi == 1:
    print("Pemenangnya adalah Teroris")
elif hasil_prediksi == 0:
    print("Pemenangnya adalah Counter Teroris")
else:
    print("Hasil prediksi tidak valid")
# Out:
# Pemenangnya adalah Teroris
# c:\Users\Sitanggang Immanuel\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Visualisasi Data

# %%
# Visualisasi model Decision Tree
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
plt.subplots (figsize=(40,20))
plot_tree(modelDT, fontsize = 20)
plt.show()
